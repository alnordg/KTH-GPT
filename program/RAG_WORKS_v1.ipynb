# %%
pip install langchain langchain-text-splitters langchain-community bs4
# Out:
# Requirement already satisfied: langchain in ./lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: langchain-text-splitters in ./lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: langchain-community in ./lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: bs4 in ./lib/python3.12/site-packages (0.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in ./lib/python3.12/site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in ./lib/python3.12/site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./lib/python3.12/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in ./lib/python3.12/site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in ./lib/python3.12/site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in ./lib/python3.12/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./lib/python3.12/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./lib/python3.12/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./lib/python3.12/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./lib/python3.12/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in ./lib/python3.12/site-packages (from langchain-community) (0.4.49)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in ./lib/python3.12/site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: beautifulsoup4 in ./lib/python3.12/site-packages (from bs4) (4.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in ./lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (24.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in ./lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in ./lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in ./lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.10)
# Requirement already satisfied: xxhash>=3.5.0 in ./lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in ./lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in ./lib/python3.12/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: soupsieve>=1.6.1 in ./lib/python3.12/site-packages (from beautifulsoup4->bs4) (2.8)
# Requirement already satisfied: anyio in ./lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.0)
# Requirement already satisfied: httpcore==1.* in ./lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./lib/python3.12/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U "langchain[google-genai]"
# Out:
# Requirement already satisfied: langchain[google-genai] in ./lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in ./lib/python3.12/site-packages (from langchain[google-genai]) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in ./lib/python3.12/site-packages (from langchain[google-genai]) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./lib/python3.12/site-packages (from langchain[google-genai]) (2.12.5)
# Requirement already satisfied: langchain-google-genai in ./lib/python3.12/site-packages (from langchain[google-genai]) (3.2.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (0.4.49)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in ./lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in ./lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in ./lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.2.10)
# Requirement already satisfied: xxhash>=3.5.0 in ./lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./lib/python3.12/site-packages (from langchain-google-genai->langchain[google-genai]) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.9.0 in ./lib/python3.12/site-packages (from langchain-google-genai->langchain[google-genai]) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in ./lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in ./lib/python3.12/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in ./lib/python3.12/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./lib/python3.12/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in ./lib/python3.12/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (6.33.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./lib/python3.12/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in ./lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in ./lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in ./lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (0.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in ./lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in ./lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (4.9.1)
# Requirement already satisfied: anyio in ./lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (4.12.0)
# Requirement already satisfied: certifi in ./lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.0.9)
# Requirement already satisfied: idna in ./lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.11)
# Requirement already satisfied: h11>=0.16 in ./lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain[google-genai]) (2.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -qU langchain-google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -qU langchain-chroma
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# RAG agent example (drop into a Jupyter notebook and run)
# Requirements (run in a cell first if not installed):
# !pip install langchain langchain-core langchain-openai langchain-text-splitters langchain-community bs4

import os
import getpass
import bs4
from typing import Tuple

# ------------------------------
# 1) Configure LangSmith tracing
# ------------------------------
# Option A: set environment variables in the notebook (recommended for interactive use)
# You will be prompted for your LangSmith API key and your OpenAI API key.
os.environ.setdefault("LANGSMITH_TRACING", "true")
os.environ.setdefault("LANGSMITH_API_KEY", "insert_key")
os.environ.setdefault("LANGSMITH_ENDPOINT", "https://eu.api.smith.langchain.com")
os.environ.setdefault("GOOGLE_API_KEY", "insert_key")
os.environ.setdefault("LANGSMITH_PROJECT", "rag_test")
os.environ.setdefault("USER_AGENT", "kth_gpt")

if not os.environ.get("LANGSMITH_API_KEY"):
    os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter LANGSMITH_API_KEY (will not echo): ")

# Also set your model provider keys (example: OpenAI)
if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter GOOGLE_API_KEY (will not echo): ")

# With LANGSMITH_TRACING="true" and LANGSMITH_API_KEY set the LangChain SDK will emit traces to LangSmith.
# Traces become visible in https://smith.langchain.com under your account.


# ------------------------------
# 2) Imports for LangChain pieces
# ------------------------------
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Google Gemini chat model integration
from langchain.chat_models import init_chat_model

# Google Gemini embeddings
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# Chroma vector store
from langchain_chroma import Chroma

# Agent creation + tools
from langchain.agents import create_agent
from langchain.tools import tool

# Middleware for two-step RAG example
from langchain.agents.middleware import dynamic_prompt, ModelRequest

# ------------------------------
# 3) Select chat model + embeddings (Google Gemini)
# ------------------------------
# Initialize chat model via helper. Replace model name with one available to your account if needed.
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# Embeddings (Gemini embeddings)
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

# ------------------------------
# 4) Load and split documents
# ------------------------------
# Example: Lilian Weng blog article from the provided docs
#bs4_strainer = bs4.SoupStrainer(class_=("mw-content-ltr mw-parser-output"))
loader = WebBaseLoader(
    web_paths=("https://www.aftonbladet.se/sportbladet/bloggar/f1bloggen/a/M7wMEm/f1-verstappen-spelar-psykspel-infor-finalen-i-abu-dhabi",),
    #bs_kwargs={"parse_only": bs4_strainer},
)
docs = loader.load()
assert len(docs) >= 1

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    add_start_index=True,
)
all_splits = text_splitter.split_documents(docs)
print(f"Loaded {len(docs)} document(s), split into {len(all_splits)} chunks.")

# ------------------------------
# 5) Create Chroma vector store and index
# ------------------------------
vector_store = Chroma(
    collection_name="example_collection",
    embedding_function=embeddings,
    persist_directory="./chroma_langchain_db",  # change or remove if you don't want persistence
)
doc_ids = vector_store.add_documents(documents=all_splits)
print("Indexed document chunk ids (sample):", doc_ids[:3])

# ------------------------------
# 6) Tool that wraps the vector store
# ------------------------------
@tool(response_format="content_and_artifact")
def retrieve_context(query: str) -> Tuple[str, list]:
    """
    Returns (serialized_text, retrieved_documents)
    - serialized_text: a string that will be shown to the model
    - retrieved_documents: the raw Document objects are attached as artifacts
    """
    retrieved_docs = vector_store.similarity_search(query, k=2)
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\nContent: {doc.page_content[:1000]}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

tools = [retrieve_context]

# ------------------------------
# 7) Build a simple agent (agentic RAG)
# ------------------------------
system_prompt = (
    "You have access to a tool that retrieves context from a website. "
    "Use the tool to help answer user queries. If you need supporting evidence, call the tool."
)
agent = create_agent(model, tools, system_prompt=system_prompt)

# Example: run an agentic RAG query (the agent may call the retrieve_context tool)
query = "Who is Max Verstappen?"
print("\n--- Agentic RAG run (streamed) ---\n")
for event in agent.stream({"messages": [{"role": "user", "content": query}]}, stream_mode="values"):
    event["messages"][-1].pretty_print()

# ------------------------------
# 8) Two-step RAG (single LLM call): use dynamic_prompt middleware
# ------------------------------
@dynamic_prompt
def prompt_with_context(request: ModelRequest) -> str:
    """Inject retrieved context based on the last user message into the system prompt."""
    last_query = request.state["messages"][-1].text
    retrieved_docs = vector_store.similarity_search(last_query, k=2)
    docs_content = "\n\n".join(doc.page_content for doc in retrieved_docs)
    system_message = (
        "You are a helpful assistant. Use the following context in your response:\n\n"
        f"{docs_content}\n\n"
        "Answer the user's question using ONLY the context above where relevant; if no answer is available, say you don't know."
    )
    return system_message

agent_two_step = create_agent(model, tools=[], middleware=[prompt_with_context])

query2 = "What did Verstappen say in the interview"
print("\n--- Two-step RAG run (single call, streamed) ---\n")
for event in agent_two_step.stream({"messages": [{"role": "user", "content": query2}]}, stream_mode="values"):
    event["messages"][-1].pretty_print()

# ------------------------------
# 9) LangSmith tracing notes
# ------------------------------
# - With LANGSMITH_TRACING="true" and LANGSMITH_API_KEY set, LangChain will emit traces to LangSmith automatically.
# - Each run (tool calls, model calls, messages, artifacts) will be available in your LangSmith workspace:
#   https://smith.langchain.com
# - If traces do not appear: verify LANGSMITH_API_KEY, LANGSMITH_TRACING, and that your environment has network access.
# Out:
# Loaded 1 document(s), split into 11 chunks.
# Indexed document chunk ids (sample): ['2b9e8b49-6cda-45a5-8b54-f5cc0fe6d092', '94512ac3-bd6a-4f4b-ba3f-43bd3b3c370d', 'b8002435-3996-45d4-86c2-d7728112c73b']
#
# --- Agentic RAG run (streamed) ---
#
# ================================ Human Message =================================
#
# Who is Max Verstappen?
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (b3b30aeb-7dc5-4b61-8e53-3e825aaad24c)
#  Call ID: b3b30aeb-7dc5-4b61-8e53-3e825aaad24c
#   Args:
#     query: Who is Max Verstappen?
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'source': 'https://www.aftonbladet.se/sportbladet/bloggar/f1bloggen/a/M7wMEm/f1-verstappen-spelar-psykspel-infor-finalen-i-abu-dhabi', 'title': 'F1: ”Verstappen spelar psykspel inför finalen i Abu Dhabi”', 'description': 'Max Verstappen har siktet inställt. På sin femte VM-titel. För att nå den behöver han hjälp och för att lyckas tar han till omdiskuterade metoder. – Han spelar', 'language': 'sv', 'start_index': 156}
# Content: Hoppa till innehållonsdag 3 december 2025Dagens namn: Lydia, CorneliaStartSportPlusHejNöjeTipsaKulturLedareTVsearchsökFormel 1|Yuki TsunodaIsack Hadjarchevron-downBloggar/F1-bloggen/Formel 1Experten: ”Verstappen spelar psykspel”Anna Anderssonchevron-rightUppdaterad 12.52 | Publicerad 11.11plusFöljemailMejlashare-arrowDelaunsaveSparacomments10Max Verstappen har siktet inställt. På sin femte VM-titel.För att nå den behöver han hjälp och för att lyckas tar han till omdiskuterade metoder.– Han spelar psykspel med McLaren, säger F1-experten Martin Brundle.expand-lefthelskärmMax Verstappen och Lando Norris Foto: Andre Penner / APTre förare går in i VM-finalen i Formel 1 med möjligheter att vinna VM-titeln. Lando Norris har bäst förutsättningar. McLarens VM-ledare behöver säkra en pallplats för att vinna sin första VM-titel, något som under normala omständigheter inte ska vara något problem alls för det stall som dominerat säsongen.VM-tvåan Max Verstappen behöver däremot hjälp för att säkra
#
# Source: {'language': 'sv', 'start_index': 156, 'title': 'F1: ”Verstappen spelar psykspel inför finalen i Abu Dhabi”', 'description': 'Max Verstappen har siktet inställt. På sin femte VM-titel. För att nå den behöver han hjälp och för att lyckas tar han till omdiskuterade metoder. – Han spelar', 'source': 'https://www.aftonbladet.se/sportbladet/bloggar/f1bloggen/a/M7wMEm/f1-verstappen-spelar-psykspel-infor-finalen-i-abu-dhabi'}
# Content: Hoppa till innehållonsdag 3 december 2025Dagens namn: Lydia, CorneliaStartSportPlusHejNöjeTipsaKulturLedareTVsearchsökFormel 1|Yuki TsunodaIsack Hadjarchevron-downBloggar/F1-bloggen/Formel 1Experten: ”Verstappen spelar psykspel”Anna Anderssonchevron-rightUppdaterad 12.52 | Publicerad 11.11plusFöljemailMejlashare-arrowDelaunsaveSparacomments10Max Verstappen har siktet inställt. På sin femte VM-titel.För att nå den behöver han hjälp och för att lyckas tar han till omdiskuterade metoder.– Han spelar psykspel med McLaren, säger F1-experten Martin Brundle.expand-lefthelskärmMax Verstappen och Lando Norris Foto: Andre Penner / APTre förare går in i VM-finalen i Formel 1 med möjligheter att vinna VM-titeln. Lando Norris har bäst förutsättningar. McLarens VM-ledare behöver säkra en pallplats för att vinna sin första VM-titel, något som under normala omständigheter inte ska vara något problem alls för det stall som dominerat säsongen.VM-tvåan Max Verstappen behöver däremot hjälp för att säkra
# ================================== Ai Message ==================================
#
# Max Verstappen is a Formula 1 driver who is aiming for his fifth World Championship title. He is known to use psychological tactics, with F1 expert Martin Brundle stating that Verstappen is "playing mind games with McLaren." In a particular instance mentioned, Verstappen and Lando Norris were in contention for the World Championship title, with Norris having the best chance to win. McLaren, Norris's team, had dominated the season, but Verstappen needed assistance to secure the championship.
#
# --- Two-step RAG run (single call, streamed) ---
#
# ================================ Human Message =================================
#
# What did Verstappen say in the interview
# ================================== Ai Message ==================================
#
# In the interview, Max Verstappen stated that he is much more relaxed now compared to his feelings before his first decisive World Championship final in 2021. He mentioned that he is 12 points behind and is approaching the situation with only positive energy, intending to do his best. He also added that even if he doesn't win, he knows he has had a fantastic season, which removes a lot of the pressure.
